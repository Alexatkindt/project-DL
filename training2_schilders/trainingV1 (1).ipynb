# %%
# !unzip -qq /content/drive/MyDrive/dataset_2Painters.zip

# %% [markdown]
# Splitting van data in Train,Validation en test

# %%
import os
import shutil
import random

# Define your directories
original_dir = "dataset_2Painters"  # Your main dataset directory
new_base_dir = "dataset_2Painters_organized"  # Where to put the organized data

# Define the categories (artists in your case)
artists = ('Mondriaan', 'Picasso')
subsets = ('train', 'validation', 'test')

# Create directories
for subset in subsets:
    for artist in artists:
        os.makedirs(os.path.join(new_base_dir, subset, artist), exist_ok=True)

# Process each artist separately to maintain balanced ratios
for artist in artists:
    artist_dir = os.path.join(original_dir, artist)
    if not os.path.exists(artist_dir):
        print(f"Warning: Directory {artist_dir} not found!")
        continue

    # Get files for this artist
    files = os.listdir(artist_dir)
    random.seed(42)  # For reproducibility
    random.shuffle(files)

    # Calculate split points
    total = len(files)
    train_end = int(0.7 * total)
    val_end = int(0.85 * total)

    # Split into subsets
    train_files = files[:train_end]
    val_files = files[train_end:val_end]
    test_files = files[val_end:]

    # Copy files to their respective directories
    for filename in train_files:
        shutil.copy2(os.path.join(artist_dir, filename),
                    os.path.join(new_base_dir, 'train', artist, filename))

    for filename in val_files:
        shutil.copy2(os.path.join(artist_dir, filename),
                    os.path.join(new_base_dir, 'validation', artist, filename))

    for filename in test_files:
        shutil.copy2(os.path.join(artist_dir, filename),
                    os.path.join(new_base_dir, 'test', artist, filename))

    print(f"{artist}: Split {len(train_files)} train, {len(val_files)} validation, {len(test_files)} test")

# Check results
for subset in subsets:
    for artist in artists:
        print(subset, artist, ':', len(os.listdir(os.path.join(new_base_dir, subset, artist))))
# Out:
# Mondriaan: Split 188 train, 40 validation, 41 test
# Picasso: Split 900 train, 193 validation, 194 test
# train Mondriaan : 188
# train Picasso : 900
# validation Mondriaan : 40
# validation Picasso : 193
# test Mondriaan : 41
# test Picasso : 194

# %%
import os

# Define your directories - use the organized structure
original_dir = "dataset_2Painters_organized"

# Define the structure for your painters dataset
subsets = ('train', 'validation', 'test')  # Common practice to list train first
artists = ('Mondriaan', 'Picasso')  # Your artist categories instead of animals

# Check and print file counts for each subset and artist
for subset in subsets:
    for artist in artists:
        path = os.path.join(original_dir, subset, artist)
        if os.path.exists(path):
            print(subset, artist, ':', len(os.listdir(path)))
        else:
            print(subset, artist, ': directory not found -', path)
# Out:
# train Mondriaan : 188
# train Picasso : 900
# validation Mondriaan : 40
# validation Picasso : 193
# test Mondriaan : 41
# test Picasso : 194

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1/.255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
#x = layers.MaxPooling(pool_size=2)(x) halveer je het nog eens is onnodig
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"]
)

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    os.path.join(new_base_dir, "train"),
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    os.path.join(new_base_dir, "validation"),
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    os.path.join(new_base_dir, "test"),
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 1088 files belonging to 2 classes.
# Found 233 files belonging to 2 classes.
# Found 235 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %%
print(type(train_dataset))
print(type(validation_dataset))
print(type(test_dataset))
# Out:
# <class 'tensorflow.python.data.ops.prefetch_op._PrefetchDataset'>
# <class 'tensorflow.python.data.ops.prefetch_op._PrefetchDataset'>
# <class 'tensorflow.python.data.ops.prefetch_op._PrefetchDataset'>

# %%
import numpy as np
import tensorflow as tf

random_numbers = np.random.normal(size=(1000, 16))  # random normaal verdeelde getallen
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)
dataset
# Out:
# <_TensorSliceDataset element_spec=TensorSpec(shape=(16,), dtype=tf.float64, name=None)>

# %%
# de data batchen
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2: break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
# map() toepassen om data te reshapen van (16, ) naar (4, 4)
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2: break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
    filepath="convnet_from_scratch.keras",  # file waarin model wordt opgeslagen
    save_best_only=True,
    monitor="val_loss")
]

# %%
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 16s 271ms/step - accuracy: 0.6475 - loss: 845.5093 - val_accuracy: 0.8326 - val_loss: 0.4354
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 202ms/step - accuracy: 0.8352 - loss: 0.7326 - val_accuracy: 0.7768 - val_loss: 0.5055
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.7640 - loss: 1.1758 - val_accuracy: 0.8283 - val_loss: 0.4712
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step - accuracy: 0.7818 - loss: 0.8247 - val_accuracy: 0.8155 - val_loss: 0.4767
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.8179 - loss: 0.4743 - val_accuracy: 0.8326 - val_loss: 0.4062
# Epoch 6/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - accuracy: 0.8268 - loss: 0.5346 - val_accuracy: 0.7039 - val_loss: 0.5367
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.8056 - loss: 0.5544 - val_accuracy: 0.7468 - val_loss: 0.4596
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.8326 - loss: 0.4834 - val_accuracy: 0.8369 - val_loss: 0.5901
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.8265 - loss: 0.5216 - val_accuracy: 0.8369 - val_loss: 0.3538
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - accuracy: 0.8745 - loss: 0.3491 - val_accuracy: 0.7897 - val_loss: 0.4441
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.8767 - loss: 0.3545 - val_accuracy: 0.8412 - val_loss: 1.4990
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.8762 - loss: 0.4083 - val_accuracy: 0.8755 - val_loss: 0.4472
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.9028 - loss: 0.3817 - val_accuracy: 0.8455 - val_loss: 0.5041
# Epoch 14/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 232ms/step - accuracy: 0.8946 - loss: 0.3594 - val_accuracy: 0.8712 - val_loss: 0.4378
# Epoch 15/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - accuracy: 0.8956 - loss: 0.2818 - val_accuracy: 0.8927 - val_loss: 0.3666
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 209ms/step - accuracy: 0.9097 - loss: 0.2645 - val_accuracy: 0.8755 - val_loss: 0.3717
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.9385 - loss: 0.1618 - val_accuracy: 0.8455 - val_loss: 1.3759
# Epoch 18/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.9147 - loss: 0.2409 - val_accuracy: 0.8970 - val_loss: 0.4730
# Epoch 19/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.9367 - loss: 0.1712 - val_accuracy: 0.8927 - val_loss: 0.5463
# Epoch 20/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.9601 - loss: 0.0945 - val_accuracy: 0.8670 - val_loss: 1.4143
# Epoch 21/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - accuracy: 0.9332 - loss: 0.3250 - val_accuracy: 0.9142 - val_loss: 0.3178
# Epoch 22/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - accuracy: 0.9475 - loss: 0.1518 - val_accuracy: 0.9356 - val_loss: 0.3527
# Epoch 23/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.9678 - loss: 0.1859 - val_accuracy: 0.9056 - val_loss: 0.4026
# Epoch 24/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.9720 - loss: 0.0859 - val_accuracy: 0.8970 - val_loss: 0.4953
# Epoch 25/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.9333 - loss: 0.2955 - val_accuracy: 0.8970 - val_loss: 0.6644
# Epoch 26/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.9731 - loss: 0.0936 - val_accuracy: 0.8970 - val_loss: 0.6741
# Epoch 27/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9855 - loss: 0.0817 - val_accuracy: 0.8755 - val_loss: 0.6901
# Epoch 28/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - accuracy: 0.9682 - loss: 0.0914 - val_accuracy: 0.9227 - val_loss: 0.9757
# Epoch 29/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9705 - loss: 0.0955 - val_accuracy: 0.8798 - val_loss: 0.8503
# Epoch 30/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 189ms/step - accuracy: 0.9563 - loss: 0.1673 - val_accuracy: 0.9099 - val_loss: 1.4611

# %%
import h5py
h5py.is_hdf5("convnet_from_scratch.keras")
# Out:
# False

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 140  # figure size vergroten

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(epochs, accuracy, "bo", label="Training accuracy")
ax1.plot(epochs, val_accuracy, "b", label="Validation accuracy")
ax1.set_title("Accuracy")
ax1.legend();

ax2.plot(epochs, loss, "bo", label="Training loss")
ax2.plot(epochs, val_loss, "b", label="Validation loss")
ax2.set_title("Loss")
ax2.legend();

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.8986 - loss: 0.8609
# Test accuracy: 0.898

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 70  # figure size verkleinen
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)  # we voegen de data augmentation lagen toe aan ons model
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)  # we voegen een dropout laag toe
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"]
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
    filepath="convnet_from_scratch_with_augmentation.keras",
    save_best_only=True,
    monitor="val_loss")
]

history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 0.7464 - loss: 0.6109 - val_accuracy: 0.8283 - val_loss: 0.4529
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 170ms/step - accuracy: 0.8258 - loss: 0.5121 - val_accuracy: 0.8283 - val_loss: 0.4264
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - accuracy: 0.8416 - loss: 0.4459 - val_accuracy: 0.8283 - val_loss: 0.3859
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.8291 - loss: 0.4482 - val_accuracy: 0.8283 - val_loss: 0.8499
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 201ms/step - accuracy: 0.8403 - loss: 0.4348 - val_accuracy: 0.8283 - val_loss: 0.3980
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.8313 - loss: 0.4330 - val_accuracy: 0.8283 - val_loss: 0.3286
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 171ms/step - accuracy: 0.8401 - loss: 0.3732 - val_accuracy: 0.8584 - val_loss: 0.3113
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - accuracy: 0.8361 - loss: 0.3908 - val_accuracy: 0.8326 - val_loss: 0.3239
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.8427 - loss: 0.3787 - val_accuracy: 0.8755 - val_loss: 0.2801
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 191ms/step - accuracy: 0.8431 - loss: 0.3698 - val_accuracy: 0.8712 - val_loss: 0.2691
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 12s 240ms/step - accuracy: 0.8538 - loss: 0.3558 - val_accuracy: 0.8498 - val_loss: 0.3625
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 156ms/step - accuracy: 0.8592 - loss: 0.3275 - val_accuracy: 0.9185 - val_loss: 0.2325
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.8379 - loss: 0.3726 - val_accuracy: 0.9056 - val_loss: 0.2579
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.8736 - loss: 0.3201 - val_accuracy: 0.9013 - val_loss: 0.2352
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - accuracy: 0.8818 - loss: 0.2992 - val_accuracy: 0.9142 - val_loss: 0.2221
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.8958 - loss: 0.2934 - val_accuracy: 0.9056 - val_loss: 0.2307
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.8887 - loss: 0.2742 - val_accuracy: 0.8884 - val_loss: 0.2593
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - accuracy: 0.8934 - loss: 0.2735 - val_accuracy: 0.8927 - val_loss: 0.2191
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.8878 - loss: 0.2873 - val_accuracy: 0.8970 - val_loss: 0.2539
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.8962 - loss: 0.2399 - val_accuracy: 0.8798 - val_loss: 0.2319
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 163ms/step - accuracy: 0.9059 - loss: 0.2634 - val_accuracy: 0.9185 - val_loss: 0.2034
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - accuracy: 0.9105 - loss: 0.2365 - val_accuracy: 0.9013 - val_loss: 0.2041
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.9050 - loss: 0.2459 - val_accuracy: 0.9013 - val_loss: 0.2140
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 170ms/step - accuracy: 0.9165 - loss: 0.2243 - val_accuracy: 0.9313 - val_loss: 0.2005
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.9160 - loss: 0.2473 - val_accuracy: 0.9099 - val_loss: 0.2011
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9152 - loss: 0.2450 - val_accuracy: 0.9056 - val_loss: 0.2159
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9150 - loss: 0.2375 - val_accuracy: 0.9227 - val_loss: 0.2387
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.8950 - loss: 0.2595 - val_accuracy: 0.8884 - val_loss: 0.2982
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - accuracy: 0.9252 - loss: 0.2161 - val_accuracy: 0.9056 - val_loss: 0.2187
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.9231 - loss: 0.1798 - val_accuracy: 0.8884 - val_loss: 0.2941
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - accuracy: 0.9181 - loss: 0.2265 - val_accuracy: 0.9270 - val_loss: 0.1753
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 12s 196ms/step - accuracy: 0.9262 - loss: 0.2042 - val_accuracy: 0.9313 - val_loss: 0.1760
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.9315 - loss: 0.1825 - val_accuracy: 0.9099 - val_loss: 0.3117
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - accuracy: 0.9154 - loss: 0.1981 - val_accuracy: 0.8755 - val_loss: 0.2826
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9200 - loss: 0.1968 - val_accuracy: 0.9270 - val_loss: 0.2323
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - accuracy: 0.9198 - loss: 0.1981 - val_accuracy: 0.9142 - val_loss: 0.2424
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - accuracy: 0.9230 - loss: 0.1858 - val_accuracy: 0.9056 - val_loss: 0.3294
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.9323 - loss: 0.1989 - val_accuracy: 0.9313 - val_loss: 0.1594
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.9257 - loss: 0.1778 - val_accuracy: 0.9399 - val_loss: 0.1677
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - accuracy: 0.9268 - loss: 0.1970 - val_accuracy: 0.9399 - val_loss: 0.1964
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.9351 - loss: 0.1848 - val_accuracy: 0.9442 - val_loss: 0.2734
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 12s 191ms/step - accuracy: 0.9289 - loss: 0.1867 - val_accuracy: 0.9442 - val_loss: 0.1615
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.9410 - loss: 0.1472 - val_accuracy: 0.9056 - val_loss: 0.2965
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9361 - loss: 0.1665 - val_accuracy: 0.8026 - val_loss: 0.7526
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 232ms/step - accuracy: 0.9262 - loss: 0.1998 - val_accuracy: 0.9270 - val_loss: 0.2265
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.9329 - loss: 0.1656 - val_accuracy: 0.9485 - val_loss: 0.1291
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - accuracy: 0.9466 - loss: 0.1481 - val_accuracy: 0.9485 - val_loss: 0.1914
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - accuracy: 0.9484 - loss: 0.1232 - val_accuracy: 0.9399 - val_loss: 0.1532
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 0.9447 - loss: 0.1464 - val_accuracy: 0.9356 - val_loss: 0.2712
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 190ms/step - accuracy: 0.9527 - loss: 0.1579 - val_accuracy: 0.9356 - val_loss: 0.2640
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - accuracy: 0.9599 - loss: 0.1139 - val_accuracy: 0.9442 - val_loss: 0.2081
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 12s 204ms/step - accuracy: 0.9624 - loss: 0.1379 - val_accuracy: 0.9614 - val_loss: 0.1058
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.9586 - loss: 0.1209 - val_accuracy: 0.9571 - val_loss: 0.1145
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - accuracy: 0.9662 - loss: 0.0961 - val_accuracy: 0.9528 - val_loss: 0.1285
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.9556 - loss: 0.1231 - val_accuracy: 0.9313 - val_loss: 0.2319
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.9526 - loss: 0.1196 - val_accuracy: 0.9099 - val_loss: 0.3045
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.9674 - loss: 0.1100 - val_accuracy: 0.9485 - val_loss: 0.1531
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step - accuracy: 0.9803 - loss: 0.0744 - val_accuracy: 0.9485 - val_loss: 0.2269
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9665 - loss: 0.0883 - val_accuracy: 0.9313 - val_loss: 0.1581
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9644 - loss: 0.1006 - val_accuracy: 0.9485 - val_loss: 0.1837
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9694 - loss: 0.0926 - val_accuracy: 0.9571 - val_loss: 0.1285
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.9609 - loss: 0.0896 - val_accuracy: 0.9571 - val_loss: 0.1331
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9642 - loss: 0.1115 - val_accuracy: 0.9571 - val_loss: 0.0825
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9805 - loss: 0.0531 - val_accuracy: 0.9528 - val_loss: 0.2288
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9560 - loss: 0.1305 - val_accuracy: 0.9742 - val_loss: 0.1105
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.9783 - loss: 0.0617 - val_accuracy: 0.9700 - val_loss: 0.0865
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.9777 - loss: 0.0848 - val_accuracy: 0.9571 - val_loss: 0.0941
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9643 - loss: 0.1167 - val_accuracy: 0.9657 - val_loss: 0.1232
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9691 - loss: 0.1089 - val_accuracy: 0.9571 - val_loss: 0.0958
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9729 - loss: 0.1031 - val_accuracy: 0.9528 - val_loss: 0.1711
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 12s 200ms/step - accuracy: 0.9708 - loss: 0.0703 - val_accuracy: 0.9571 - val_loss: 0.1369
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step - accuracy: 0.9649 - loss: 0.1175 - val_accuracy: 0.9614 - val_loss: 0.1048
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 0.9653 - loss: 0.0933 - val_accuracy: 0.9485 - val_loss: 0.1076
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.9607 - loss: 0.1221 - val_accuracy: 0.9399 - val_loss: 0.1721
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - accuracy: 0.9544 - loss: 0.1580 - val_accuracy: 0.9571 - val_loss: 0.0978
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9804 - loss: 0.0476 - val_accuracy: 0.9657 - val_loss: 0.1064
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 150ms/step - accuracy: 0.9617 - loss: 0.1102 - val_accuracy: 0.9657 - val_loss: 0.0882
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 165ms/step - accuracy: 0.9745 - loss: 0.0573 - val_accuracy: 0.9528 - val_loss: 0.1852
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - accuracy: 0.9613 - loss: 0.1302 - val_accuracy: 0.9185 - val_loss: 0.3207
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9755 - loss: 0.0645 - val_accuracy: 0.9185 - val_loss: 0.2675
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 173ms/step - accuracy: 0.9752 - loss: 0.1003 - val_accuracy: 0.9485 - val_loss: 0.1422
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 211ms/step - accuracy: 0.9717 - loss: 0.0866 - val_accuracy: 0.9657 - val_loss: 0.1563
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 178ms/step - accuracy: 0.9739 - loss: 0.0607 - val_accuracy: 0.9614 - val_loss: 0.1237
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 150ms/step - accuracy: 0.9704 - loss: 0.0794 - val_accuracy: 0.9742 - val_loss: 0.0930
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - accuracy: 0.9757 - loss: 0.0797 - val_accuracy: 0.9700 - val_loss: 0.0747
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9863 - loss: 0.0395 - val_accuracy: 0.9700 - val_loss: 0.0970
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - accuracy: 0.9805 - loss: 0.0815 - val_accuracy: 0.9742 - val_loss: 0.0743
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 228ms/step - accuracy: 0.9703 - loss: 0.0854 - val_accuracy: 0.9785 - val_loss: 0.0819
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 0.9782 - loss: 0.0550 - val_accuracy: 0.9700 - val_loss: 0.1094
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - accuracy: 0.9765 - loss: 0.0754 - val_accuracy: 0.9785 - val_loss: 0.0514
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.9920 - loss: 0.0337 - val_accuracy: 0.9700 - val_loss: 0.2845
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.9668 - loss: 0.1673 - val_accuracy: 0.9528 - val_loss: 0.1055
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 166ms/step - accuracy: 0.9808 - loss: 0.0754 - val_accuracy: 0.9785 - val_loss: 0.0524
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 239ms/step - accuracy: 0.9714 - loss: 0.0908 - val_accuracy: 0.9571 - val_loss: 0.1154
# Epoch 95/100
# 24/34 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9741 - loss: 0.1368

# %%
plt.rcParams['figure.dpi'] = 140  # figure size vergroten

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(epochs, accuracy, "bo", label="Training accuracy")
ax1.plot(epochs, val_accuracy, "b", label="Validation accuracy")
ax1.set_title("Accuracy")
ax1.legend();

ax2.plot(epochs, loss, "bo", label="Training loss")
ax2.plot(epochs, val_loss, "b", label="Validation loss")
ax2.set_title("Loss")
ax2.legend();

# %%
test_model = keras.models.load_model("convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")

# %%
from tensorflow import keras

conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3)
)

# %%
conv_base.summary()

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)

# %%
print('Training:')
print("\tfeatures:", train_features.shape)
print("\tlabels:", train_labels.shape)
print('Validation:')
print("\tfeatures:", val_features.shape)
print("\tlabels:", val_labels.shape)
print('Test:')
print("\tfeatures:", test_features.shape)
print("\tlabels:", test_labels.shape)

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"]
)

# %%
callbacks = [keras.callbacks.ModelCheckpoint(
    filepath="feature_extraction.keras",
    save_best_only=True,
    monitor="val_loss")]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks
)

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 125  # figure size vergroten

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(epochs, acc, "bo", label="Training accuracy")
ax1.plot(epochs, val_acc, "b", label="Validation accuracy")
ax1.set_title("Accuracy")
ax1.legend();

ax2.plot(epochs, loss, "bo", label="Training loss")
ax2.plot(epochs, val_loss, "b", label="Validation loss")
ax2.set_title("Loss")
ax2.legend();

# %%
from tensorflow import keras

conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
)

# %%
conv_base.trainable = True
print("This is the number of trainable weights "
      "before freezing the conv base:", len(conv_base.trainable_weights))

# %%
conv_base.trainable = False
print("This is the number of trainable weights "
      "after freezing the conv base:", len(conv_base.trainable_weights))

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"]
)

# %%
callbacks = [keras.callbacks.ModelCheckpoint(
    filepath="feature_extraction_with_data_augmentation.keras",
    save_best_only=True,
    monitor="val_loss")]

history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks
)

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(epochs, acc, "bo", label="Training accuracy")
ax1.plot(epochs, val_acc, "b", label="Validation accuracy")
ax1.set_title("Accuracy")
ax1.legend();

ax2.plot(epochs, loss, "bo", label="Training loss")
ax2.plot(epochs, val_loss, "b", label="Validation loss")
ax2.set_title("Loss")
ax2.legend();

# %%
test_model = keras.models.load_model("feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-2]:
    layer.trainable = False

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
    metrics=["accuracy"]
)

callbacks = [keras.callbacks.ModelCheckpoint(
    filepath="fine_tuning.keras",
    save_best_only=True,
    monitor="val_loss")]

history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks
)

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(epochs, acc, "bo", label="Training accuracy")
ax1.plot(epochs, val_acc, "b", label="Validation accuracy")
ax1.set_title("Accuracy")
ax1.legend();

ax2.plot(epochs, loss, "bo", label="Training loss")
ax2.plot(epochs, val_loss, "b", label="Validation loss")
ax2.set_title("Loss")
ax2.legend();

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
